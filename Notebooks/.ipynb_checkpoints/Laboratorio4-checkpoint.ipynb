# %%
#Limpieza y Transformación de los datos

Fecha: 29 de mayo del 2026
Autor: YO (Adri)
# Out:
#   Cell In[1], line 3
#     Fecha: 29 de mayo del 2026
#               ^
# SyntaxError: invalid syntax

# %%
#Limpieza y Transformación de los datos

#Fecha: 29 de mayo del 2026

# %%
# Importamos librerias principales

import pandas as pd

import numpy as np #Trabajar datos y series

# %%
#Importamos librerias para graficas 
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
#Cargamos el dataset crudo/suplo

dfCrudo = pd.read_csv("../Data/dataset_sucio_practica.csv")

# %%
dfCrudo
# Out:
#      id          nombre   edad                 correo       pais  salario  \
# 0     1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 1     2             NaN   35.0     asimmons@garza.com     España      NaN
# 2     3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 3     4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 4     5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
# ..   ..             ...    ...                    ...        ...      ...
# 120   1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 121   2             NaN   35.0     asimmons@garza.com     España      NaN
# 122   3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 123   4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 124   5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
#
#     fecha_registro activo
# 0       2026-03-09     Sí
# ...

# %%
#Generar una copia del dataframe

dfCrudoCopia = dfCrudo.copy()

# %%
#Vamos a mostrar los valores nulos

dfCrudoCopia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              125 non-null    int64
#  1   nombre          116 non-null    object
#  2   edad            110 non-null    float64
#  3   correo          125 non-null    object
#  4   pais            82 non-null     object
#  5   salario         107 non-null    float64
#  6   fecha_registro  125 non-null    object
#  7   activo          90 non-null     object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 7.9+ KB

# %%
dfCrudoCopia.describe()
# Out:
#                id        edad       salario
# count  125.000000  110.000000    107.000000
# mean    58.200000   43.945455  14093.457944
# std     35.906465   47.489803   8825.918852
# min      1.000000   -5.000000  -1000.000000
# 25%     27.000000   22.750000  12000.000000
# 50%     58.000000   30.000000  15000.000000
# 75%     89.000000   40.000000  18000.000000
# max    120.000000  150.000000  25000.000000

# %%
#Mostramos el total de valores nu

dfCrudoCopia.isnull().sum()
# Out:
# id                 0
# nombre             9
# edad              15
# correo             0
# pais              43
# salario           18
# fecha_registro     0
# activo            35
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dfCrudoCopia.isnull(), cbar=False)
plt.title("Mapa de calor de valores nulos")
plt.show()

# %%
#LIMPIEZA DE DATOS de liputight <Eliminar datos duplicados Imputar valores nulos Corregir outlier (Valores fuera de rango)

# %%
import seaborn as sns

# %%
#1. Eliminamos datos duplicados

dfCrudoCopia.duplicated().sum()
# Out:
# np.int64(0)

# %%
dfCrudoCopia.drop_duplicates(inplace=True) #Elimina datos duplicados

# %%
# 2. Verificamos la existencia de edades fuera de rango

dfCrudoCopia [(dfCrudoCopia[edad]<0)](dfSucioCrudo ["edad"]>100)]
# Out:
#   Cell In[26], line 3
#     dfCrudoCopia [(dfCrudoCopia[edad]<0)](dfSucioCrudo ["edad"]>100)]
#                                                                     ^
# SyntaxError: unmatched ']'

# %%
#VERIFICAMOS EXISTENCIA DE EDADES FUERA DE RANGO
dfCrudoCopia[(dfCrudoCopia["edad"]<0)| (dfCrudoCopia["edad"]>100)]
# Out:
#       id              nombre   edad                                 correo  \
# 0      1         Julia Zhang  150.0                       aortiz@perry.com
# 4      5      Elaine Sanchez   -5.0                        correo_invalido
# 6      7       Roberto Smith   -5.0                     vegasara@yahoo.com
# 7      8     Nicholas Torres   -5.0                   arnoldjoe@macias.biz
# 9     10     Angela Richards   -5.0               rubiogabrielle@yahoo.com
# 12    13            Paul Liu  150.0                        ilong@gmail.com
# 16    17   Christopher Klein   -5.0                  ericarice@hotmail.com
# 22    23   Mrs. Diane Carter  150.0               schultzpatrick@mccoy.net
# 23    24          Vicki Love   -5.0                  antonio14@johnson.net
# 24    25      Matthew Porter   -5.0                hansoncameron@yahoo.com
# 38    39       Rose Williams   -5.0                     jesus70@berger.org
# ...

# %%
#Convertimos las edades invalidas en NaN
dfCrudoCopia.loc[
    (dfCrudoCopia["edad"]<0) | (dfCrudoCopia["edad"]>100), "edad"
] = np.nan

# %%
#VERIFICAMOS EXISTENCIA DE EDADES FUERA DE RANGO
dfCrudoCopia[(dfCrudoCopia["edad"]<0)| (dfCrudoCopia["edad"]>100)]
# Out:
# Empty DataFrame
# Columns: [id, nombre, edad, correo, pais, salario, fecha_registro, activo]
# Index: []

# %%
mediana_edad = dfCrudoCopia["edad"].median()
mediana_edad
# Out:
# 30.0

# %%
dfCrudoCopia ["edad"]= dfCrudoCopia["edad"].fillna(mediana_edad)

# %%
dfCrudoCopia["edad"].describe()
# Out:
# count    120.000000
# mean      30.325000
# std        4.745918
# min       22.000000
# 25%       30.000000
# 50%       30.000000
# 75%       31.250000
# max       40.000000
# Name: edad, dtype: float64

# %%
# 2. Verificamos la existencia de salario fuera de rango

dfCrudoCopia [(dfCrudoCopia[salario]<0)](dfSucioCrudo ["salario"]>20000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # 2. Verificamos la existencia de salario fuera de rango
# ----> 3 dfCrudoCopia [(dfCrudoCopia[salario]<0)](dfSucioCrudo ["salario"]>20000)
#
# NameError: name 'salario' is not defined

# %%
# Identificar los salarios negativos

dfCrudoCopia [

(dfCrudoCopia ["salario"]<)]
# Out:
#   Cell In[36], line 5
#     (dfCrudoCopia ["salario"]<)]
#                               ^
# SyntaxError: invalid syntax

# %%
# Identificar los salarios negativos

dfCrudoCopia [(dfCrudoCopia ["salario"]<)]
# Out:
#   Cell In[37], line 3
#     dfCrudoCopia [(dfCrudoCopia ["salario"]<)]
#                                             ^
# SyntaxError: invalid syntax

# %%
# Identificar los salarios negativos

dfCrudoCopia [(dfCrudoCopia ["salario"]<)]
# Out:
#   Cell In[38], line 3
#     dfCrudoCopia [(dfCrudoCopia ["salario"]<)]
#                                             ^
# SyntaxError: invalid syntax

# %%
# Identificar los salarios negativos

dfCrudoCopia [(dfCrudoCopia ["salario"]<0)]
# Out:
#       id              nombre  edad                                 correo  \
# 9     10     Angela Richards  30.0               rubiogabrielle@yahoo.com
# 11    12       Daniel Wright  25.0               melissamaxwell@gmail.com
# 20    21     Marc Miller DDS  30.0          ccalderon@campbell-carter.com
# 21    22     Carrie Griffith  30.0                        correo_invalido
# 26    27        Mary Miranda  40.0                  brendaglenn@gmail.com
# 27    28         John Taylor  30.0                jonesashley@hotmail.com
# 28    29        Teresa Ramos  22.0               rileyraymond@hotmail.com
# 37    38       Brian Sherman  30.0                    brianna61@yahoo.com
# 41    42   Patricia Morrison  30.0                       uweiss@yahoo.com
# 44    45        John Estrada  35.0                  nichole26@hotmail.com
# 45    46       Jeremy Cooper  35.0                 vfrederick@hotmail.com
# 48    49        Willie Marks  30.0                   joshua86@farrell.com
# ...

# %%
# Convertimos los salarios inválidos (negativos) en NaN
dfCrudoCopia.loc[dfCrudoCopia["salario"] < 0, "salario"] = np.nan

# %%
# Calculamos la mediana de la columna salario
mediana_salario = dfCrudoCopia["salario"].median()
mediana_salario
# Out:
# 15000.0

# %%
# Rellenamos los salarios nulos con la mediana calculada
dfCrudoCopia["salario"] = dfCrudoCopia["salario"].fillna(mediana_salario)

# %%
# Verificamos la distribución final de los salarios
dfCrudoCopia["salario"].describe()
# Out:
# count      120.000000
# mean     16741.666667
# std       4401.099621
# min      12000.000000
# 25%      15000.000000
# 50%      15000.000000
# 75%      18000.000000
# max      25000.000000
# Name: salario, dtype: float64

# %%
# Variables de tipo cadena / string / object

dfCrudoCopia [
~dfCrudoCopia ["correo"].str.contains("@", na=False)
    ]
# Out:
#     id             nombre  edad           correo       pais  salario  \
# 3    4     Joyce Williams  30.0  correo_invalido  Argentina  25000.0
# 4    5     Elaine Sanchez  30.0  correo_invalido     México  25000.0
# 18  19     Nicholas Curry  35.0  correo_invalido     México  12000.0
# 21  22    Carrie Griffith  30.0  correo_invalido        NaN  15000.0
# 30  31  Mrs. Sara Johnson  35.0  correo_invalido  Argentina  15000.0
# 40  41     Cynthia Arnold  30.0  correo_invalido        NaN  25000.0
# 65  66      Michael Lopez  40.0  correo_invalido     España  15000.0
# 78  79       Charles Page  25.0  correo_invalido        NaN  15000.0
# 87  88                NaN  22.0  correo_invalido        NaN  12000.0
# 88  89      Erika Bernard  30.0  correo_invalido  Argentina  12000.0
# 94  95        Daniel Wong  30.0  correo_invalido     España  15000.0
# 95  96         Luis Drake  25.0  correo_invalido        NaN  25000.0
#
#    fecha_registro activo
# 3      2025-02-23     No
# ...

# %%
correos_invalidos= dfCrudoCopia["correo"].str.contains("@", na=False)
correos_invalidos
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 115     True
# 116     True
# 117     True
# 118     True
# 119     True
# Name: correo, Length: 120, dtype: bool

# %%
dfCrudoCopia.loc [correos_invalidos, "correo"] = pd.NA

# %%
dfCrudoCopia ["correo_valido"] = dfCrudoCopia ["correo"].str.contains("@", na=False)

# %%
#Mostramos los primeros 5 registros

dfCrudoCopia.head(5)
# Out:
#    id          nombre  edad           correo       pais  salario  \
# 0   1     Julia Zhang  30.0             <NA>        NaN  25000.0
# 1   2             NaN  35.0             <NA>     España  15000.0
# 2   3    George Burke  40.0             <NA>  Argentina  15000.0
# 3   4  Joyce Williams  30.0  correo_invalido  Argentina  25000.0
# 4   5  Elaine Sanchez  30.0  correo_invalido     México  25000.0
#
#   fecha_registro activo  correo_valido
# 0     2026-03-09     Sí          False
# 1     2026-05-04     No          False
# 2     2026-01-27    NaN          False
# 3     2025-02-23     No          False
# 4     2025-03-28     Sí          False

# %%
# Revisamos la columna Pais
dfCrudoCopia ["pais").isnull().sum)
# Out:
#   Cell In[50], line 2
#     dfCrudoCopia ["pais").isnull().sum)
#                         ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
:

# Revisamos la columna Pais

dfCrudoCopia ["pais"].isnull().sum)
# Out:
#   Cell In[51], line 5
#     dfCrudoCopia ["pais"].isnull().sum)
#                                       ^
# SyntaxError: unmatched ')'

# %%
:

# Revisamos la columna Pais

dfCrudoCopia ["pais"].isnull().sum()
# Out:
#   Cell In[52], line 1
#     :
#     ^
# SyntaxError: invalid syntax

# %%
# Revisamos la columna Pais

dfCrudoCopia ["pais"].isnull().sum()
# Out:
# np.int64(42)

# %%
dfCrudoCopia[

dfCrudoCopia

    ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20276\2007066892.py in ?()
# ----> 1 dfCrudoCopia[
#       2
#       3 dfCrudoCopia
#       4
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
#   11045                     )
#   11046
#   11047         other = common.apply_if_callable(other, self)
# ...

# %%
# Identificamos el pais más repetido

dfCrudoCopia ["pais").mode() [0]
# Out:
#   Cell In[61], line 3
#     dfCrudoCopia ["pais").mode() [0]
#                         ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
# Identificamos el pais más repetido

dfCrudoCopia ["pais"].mode() [0]
# Out:
# 'Argentina'

# %%
#Asignamos el país de

dfCrudoCopia ["pais"] = dfCrudoCopia ["pais"].fillna(pais_moda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 #Asignamos el país de
# ----> 3 dfCrudoCopia ["pais"] = dfCrudoCopia ["pais"].fillna(pais_moda)
#
# NameError: name 'pais_moda' is not defined

# %%
dfCrudoCopia["pais").isnull().sum()
# Out:
#   Cell In[58], line 1
#     dfCrudoCopia["pais").isnull().sum()
#                        ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
# Identificamos el país más repetido y lo guardamos en la variable
pais_moda = dfCrudoCopia["pais"].mode()[0]
pais_moda
# Out:
# 'Argentina'

# %%
# Asignamos el país de moda a los valores faltantes
dfCrudoCopia["pais"] = dfCrudoCopia["pais"].fillna(pais_moda)

# %%
dfCrudoCopia["pais"].isnull().sum()
# Out:
# np.int64(0)

# %%
#Verificar los tipos de datos

dfCrudoCopia.dtypes
# Out:
# id                  int64
# nombre             object
# edad              float64
# correo             object
# pais               object
# salario           float64
# fecha_registro     object
# activo             object
# correo_valido        bool
# dtype: object

# %%
#Convertimos la fecha registro a DateTime

dfCrudoCopia ["fecha_registro"] = pd.to_datetime(dfCrudoCopia["fecha_registro"])

# %%
#Mostramos el tipo de dato

dfCrudoCopia ["fecha_registro"].dtype
# Out:
# dtype('<M8[ns]')

# %%
dfCrudoCopia.dtypes
# Out:
# id                         int64
# nombre                    object
# edad                     float64
# correo                    object
# pais                      object
# salario                  float64
# fecha_registro    datetime64[ns]
# activo                    object
# correo_valido               bool
# dtype: object

# %%
#Campo activo

dfCrudoCopia ["activo"].value_counts(dropna=False)
# Out:
# activo
# Sí     47
# No     39
# NaN    34
# Name: count, dtype: int64

# %%
dfCrudoCopia ["active"]= dfCrudoCopia ["activo"].fillna("Si")

# %%
dfCrudoCopia["activo"].value_counts(dropna=False)
# Out:
# activo
# Sí     47
# No     39
# NaN    34
# Name: count, dtype: int64

# %%
# Categorizamos el campo activo

dfCrudoCopia ["activo"] = dfCrudoCopia["activo"].map(
{
"Si":1,
"No":0
})

# %%
dfCrudoCopia["activo"].value_counts(dropna=False)
# Out:
# activo
# NaN    81
# 0.0    39
# Name: count, dtype: int64

# %%
#Durante esta practica se realizaron algunos cambios de variables. Mi conclusion es que esta herramienta nos ayuda en la interpretacion de datos, así nosotros podemos identificar las variabales y datos que nos sirvan
